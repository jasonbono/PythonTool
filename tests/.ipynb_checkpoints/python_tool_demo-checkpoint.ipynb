# %%
import os
import sys
import numpy as np
print(np.version.version)
#Set the directory that contains the ROOT data
# os.environ['ARTTFSDIR'] = "~/Desktop/tempdatadir"
os.environ['ARTTFSDIR'] = "/Volumes/DataStorage/gm2/FieldData/mnt/nfs/g2field-server-2/newg2/DataProduction/Nearline/ArtTFSDir"


print("data dir = ",os.environ['ARTTFSDIR'])
# Out:
# 1.16.2
# data dir =  /Volumes/DataStorage/gm2/FieldData/mnt/nfs/g2field-server-2/newg2/DataProduction/Nearline/ArtTFSDir

# %%
#add the gm2 pyroot tool to the path (within the shell)
# sys.path.append('/Users/bono/Desktop/PythonTool/gm2/lib')
sys.path.append('/Users/bono/Desktop/PythonTool/newest/gm2/lib')

# %%
#Bypass using the thisgm2.sh file

#Set BASEDIR and GM2
# base_dir = "/Users/bono/Desktop/PythonTool/gm2"
base_dir = "/Users/bono/Desktop/PythonTool/newest/gm2"
os.environ['BASEDIR'] = base_dir
os.environ['GM2'] = base_dir
print("GM2 = ",os.environ['GM2'])

#append PYTHONPATH
python_path = os.environ['PYTHONPATH'] + ":" + base_dir + "/lib"
os.environ['PYTHONPATH'] = python_path
print("PYTHONPATH = ",os.environ['PYTHONPATH'])
# Out:
# GM2 =  /Users/bono/Desktop/PythonTool/newest/gm2
# PYTHONPATH =  /usr/local/Cellar/root/6.16.00/lib/root:/Users/bono/Desktop/PythonTool/newest/gm2/lib

# %%
#load the library
import gm2
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.16/00

# %%
# tr = gm2.Trolley([6327],"FieldPlainRootOutput_")
tr = gm2.Trolley([6327])
tr_time, tr_pos, tr_freq = tr.getBasics() # return numpy arrays with size [n_events, n_probes]
probe = 4
plt.plot(tr_pos[:,probe], tr_freq[:,probe], 'o-', lw=2,alpha=0.5)
# plt.xlim(20000,80000)
plt.title('Trolley Readings')
plt.xlabel('Position (phi)')
plt.ylabel('Frequency (Hz)')
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Reading event 9010/9014 99.96%
# loop done: 100%

# %%
freq_method = 0
evt = 5
run = 6327
fp = gm2.FixedProbe([run])
print(type(fp))

def callback():
     return [fp.getFrequency(freq_method)[probe], fp.getTimeGPS()[probe]]

fp_freq = np.empty(0)
fp_time = np.empty(0)
for evt in range(5000):
    fp.load(evt)
    a,b = callback()
    fp_freq = np.append(fp_freq, a)
    fp_time = np.append(fp_time, b)
# plt.plot(fp_time, fp_freq, 'o-', lw=2,alpha=0.5)
# plt.title('Fixed Probe {} Readings'.format(probe))
# plt.xlabel('Time (ns)')
# plt.ylabel('Frequency (Hz)')
# plt.grid()
# plt.tight_layout()
# plt.show()

gm2.plotutil.plot_ts(fp_time, fp_freq)
# Out:
# <class 'gm2.FixedProbe.FixedProbe'>

# %%
fp_freq, fp_time = fp.loop(callback)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-9441cd673d9c> in <module>
# ----> 1 fp_freq, fp_time = fp.loop(callback)
#
# ~/Desktop/PythonTool/newest/gm2/lib/gm2/FixedProbe.py in loop(self, func, ids, yokes, radIds, aziIds, layers, *args)
#     196     def loop(self, func, ids=[], yokes=[], radIds=[], aziIds=[], layers=[], *args):
#     197         """ loop function with fp specific selections """
# --> 198         self.loadIds()
#     199         self.getEntry(0)
#     200         sel = self.select(ids=ids, yokes=yokes, radIds=radIds, aziIds=aziIds, layers=layers)
#
# ~/Desktop/PythonTool/newest/gm2/lib/gm2/FixedProbe.py in loadIds(self, event)
#      69         if(self.getEntries() >= event):
#      70             self.load(event)
# ---> 71             self.id = { 'yoke':  self.getYoke(),
#      72                         'azi':   self.getAziId(),
#      73                         'rad':   self.getRadId(),
#
# ~/Desktop/PythonTool/newest/gm2/lib/gm2/FixedProbe.py in getYoke(self)
#     182
#     183     def getYoke(self):
# --> 184         return np.frombuffer(self.data.Header_YokeId, dtype='a1')
#     185
#     186     def getRadId(self):
#
# AttributeError: 'str' object has no attribute '__buffer__'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-fc7db061eb26> in <module>
#       1 def callback():
#       2      return [fp.getFrequency(freq_method)[probe], fp.getTimeGPS()[probe]]
# ----> 3 fp_freq, fp_time = fp.loop(callback)
#       4
#
# ~/Desktop/PythonTool/newest/gm2/lib/gm2/FixedProbe.py in loop(self, func, ids, yokes, radIds, aziIds, layers, *args)
#     196     def loop(self, func, ids=[], yokes=[], radIds=[], aziIds=[], layers=[], *args):
#     197         """ loop function with fp specific selections """
# --> 198         self.loadIds()
#     199         self.getEntry(0)
#     200         sel = self.select(ids=ids, yokes=yokes, radIds=radIds, aziIds=aziIds, layers=layers)
#
# ~/Desktop/PythonTool/newest/gm2/lib/gm2/FixedProbe.py in loadIds(self, event)
#      69         if(self.getEntries() >= event):
#      70             self.load(event)
# ---> 71             self.id = { 'yoke':  self.getYoke(),
#      72                         'azi':   self.getAziId(),
#      73                         'rad':   self.getRadId(),
#
# ~/Desktop/PythonTool/newest/gm2/lib/gm2/FixedProbe.py in getYoke(self)
#     182
#     183     def getYoke(self):
# --> 184         return np.frombuffer(self.data.Header_YokeId, dtype='a1')
#     185
#     186     def getRadId(self):
#
# AttributeError: 'str' object has no attribute '__buffer__'

# %%
fp_time, fp_freq = fp.getBasics()
